# %%
# %run LinearRegressionCustom.ipynb
# Out:
# Current Progress: 100.0 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   field                      755 non-null    object
#  1   zone                       755 non-null    int32
#  2   planting_date              755 non-null    datetime64[ns]
#  3   variety                    755 non-null    object
#  4   method                     755 non-null    object
#  5   inputs                     755 non-null    object
#  6   protection                 755 non-null    object
#  7   planting_rate              755 non-null    int64
#  8   sand                       755 non-null    int64
#  9   silt                       755 non-null    int64
#  10  clay                       755 non-null    int64
#  11  organic_matter             755 non-null    float64
#  12  harvest_date               515 non-null    datetime64[ns]
#  13  fieldzone                  755 non-null    object
#  14  fieldvariety               755 non-null    object
#  15  mean_pp2m2                 755 non-null    float64
#  16  max_sample_date            755 non-null    object
#  17  max_mean_diameter_lin      755 non-null    float64
#  18  max_std_dev_diameter_lin   755 non-null    float64
#  19  max_heat                   755 non-null    float64
#  20  max_solar                  755 non-null    float64
#  21  remaining_heat             755 non-null    float64
#  22  remaining_solar            755 non-null    float64
#  23  est_mean_diameter_gain     755 non-null    float64
#  24  est_std_dev_diameter_gain  755 non-null    float64
#  25  est_mean_diameter          755 non-null    float64
#  26  est_std_dev_diameter       750 non-null    float64
#  27  field_variety              755 non-null    object
# dtypes: datetime64[ns](2), float64(12), int32(1), int64(4), object(9)
# memory usage: 162.3+ KB
# None
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1835: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %%
field_data = zone_data
field_data['establishment'] = (field_data['mean_pp2m2']/2*10000)/field_data['planting_rate']

# %%
summary_data.head()
# Out:
#        fieldzone sample_date      field zone  diameter  stripped_diameter  \
# 0  Allans 06 - 1  2021-07-29  Allans 06    1      13.0              11.96
# 1  Allans 06 - 1  2021-07-29  Allans 06    1      14.0              12.88
# 2  Allans 06 - 1  2021-07-29  Allans 06    1       8.0               7.36
# 3  Allans 06 - 1  2021-07-29  Allans 06    1      10.0               9.20
# 4  Allans 06 - 1  2021-07-29  Allans 06    1       7.0               6.44
#
#                 fieldzonedate planting_date  variety   method        inputs  \
# 0  Allans 06 - 1 - 2021-07-29    2021-04-10  Krypton  Drilled  Conventional
# 1  Allans 06 - 1 - 2021-07-29    2021-04-10  Krypton  Drilled  Conventional
# 2  Allans 06 - 1 - 2021-07-29    2021-04-10  Krypton  Drilled  Conventional
# 3  Allans 06 - 1 - 2021-07-29    2021-04-10  Krypton  Drilled  Conventional
# 4  Allans 06 - 1 - 2021-07-29    2021-04-10  Krypton  Drilled  Conventional
#
#   protection  planting_rate  sand  silt  clay  organic_matter harvest_date  \
# 0     Barley       262270.0  40.0  41.0  19.0            24.6          NaT
# 1     Barley       262270.0  40.0  41.0  19.0            24.6          NaT
# 2     Barley       262270.0  40.0  41.0  19.0            24.6          NaT
# 3     Barley       262270.0  40.0  41.0  19.0            24.6          NaT
# 4     Barley       262270.0  40.0  41.0  19.0            24.6          NaT
#
#           fieldvariety  heat_units  solar_radiation
# 0  Allans 06 - Krypton           0                0
# 1  Allans 06 - Krypton           0                0
# 2  Allans 06 - Krypton           0                0
# 3  Allans 06 - Krypton           0                0
# 4  Allans 06 - Krypton           0                0

# %%
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams["savefig.jpeg_quality"] = 75
plt.rcParams["savefig.format"] = 'jpeg'

df = summary_data.query('field == "Grotec Long 15"')
df = df[df['sample_date'].isin(['03/08/2020', '11/09/2020', '24/11/2020'])]
sns.displot(df, x="stripped_diameter", hue="sample_date", kind="kde", fill=True, bw_adjust=2, common_norm=False)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
name = 'Grotec Long 15'
plt.title(name)
plt.savefig(name)
plt.show()

df = summary_data.query('field == "Grotec Long 15"')
df = df[df['sample_date'].isin(['24/11/2020'])]
sns.displot(df, x="stripped_diameter", kind="kde", color='g', fill=True, bw_adjust=2, cumulative=True)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
plt.axhline(0.09, ls='--')
plt.axhline(0.885, ls='--')
name = 'Grotec Long 15 Cumulative Distribution'
plt.title(name)
plt.savefig(name, bbox_inches='tight')
plt.show()

df = summary_data.query('field == "Garretts Decoy 3"')
sns.displot(df, x="stripped_diameter", hue="sample_date", kind="kde", fill=True, bw_adjust=2, common_norm=False)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
name = 'Garretts Decoy 3 (1)'
plt.title(name)
plt.savefig(name)
plt.show()

df = summary_data.query('field == "Garretts Decoy 3"')
df = df[df['sample_date'].isin(['19/11/2019'])]
sns.displot(df, x="stripped_diameter", kind="kde", color='g', fill=True, bw_adjust=2, common_norm=False)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
plt.xlim(0, 70)
plt.ylim(0, 0.08)
name = 'Garretts Decoy 3'
plt.title(name)
plt.savefig(name)
plt.show()

df = summary_data.query('field == "Garretts Decoy 3"')
df = df[df['sample_date'].isin(['19/11/2019'])]
sns.displot(df, x="stripped_diameter", kind="kde", color='g', fill=True, bw_adjust=2, cumulative=True)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
plt.axhline(0.02, ls='--')
plt.axhline(0.65, ls='--')
name = "Garretts Decoy 3 Cumulative Distribution"
plt.title(name)
plt.savefig(name)
plt.show()
# Out:
# <ipython-input-4-1c4fe054a14c>:2: MatplotlibDeprecationWarning:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   plt.rcParams["savefig.jpeg_quality"] = 75

# %%
df = summary_data.query('field == "Chatteris Farms 07/08" & sample_date == "24/11/2020"')
sns.displot(df, x="stripped_diameter", kind="kde", fill=True, bw_adjust=2, cumulative = False)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
plt.xlim(0, 70)
plt.ylim(0, 0.08)
name = 'Chatteris Farms 07-08'
plt.title(name)
plt.savefig(name)
plt.show()



df = summary_data.query('field == "Chatteris Farms 07/08" & sample_date == "24/11/2020"')
sns.displot(df, x="stripped_diameter", kind="kde", fill=True, bw_adjust=2, cumulative = True)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
plt.axhline(0.04, ls='--')
plt.axhline(0.98, ls='--')
name = 'Chatteris Farms 07-08 Cumulative Distribution'
plt.title(name)
plt.savefig(name)
plt.show()

# %%
df = summary_data.query('field == "Park Farm 53"')
df = df[df['sample_date'].isin(['10/07/2020', '03/08/2020', '02/10/2020'])]
sns.displot(df, x="stripped_diameter", hue="sample_date", kind="kde", fill=True, bw_adjust=2, common_norm=False)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
name = 'Park Farm 53'
plt.title(name)
plt.savefig(name)
plt.show()

df = df[df['sample_date'].isin(['02/10/2020'])]
sns.displot(df, x="stripped_diameter", kind="kde", color='g', fill=True, bw_adjust=2, cumulative=True)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
plt.axhline(0.17, ls='--')
plt.axhline(0.94, ls='--')
name = 'Park Farm 53 Cumulative Distribution'
plt.title(name)
plt.savefig(name)
plt.show()

####Talk about how curves are different for each field so optimum harvest time can't just be set at an average diameter

df = summary_data.query('field == "Wissey 27"')
df = df[df['sample_date'].isin(['09/07/2020', '20/08/2020', '15/10/2020'])]
sns.displot(df, x="stripped_diameter", hue="sample_date", kind="kde", fill=True, bw_adjust=2, common_norm=False)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
name = 'Wissey 27'
plt.title(name)
plt.savefig(name)
plt.show()

df = df[df['sample_date'].isin(['15/10/2020'])]
sns.displot(df, x="stripped_diameter", kind="kde", color='g', fill=True, bw_adjust=2, cumulative=True)
plt.axvline(x=20, color='grey')
plt.axvline(x=42, color='grey')
plt.axhline(0.2, ls='--')
plt.axhline(0.98, ls='--')
name = 'Wissey 27 Cumulative Distribution'
plt.title(name)
plt.savefig(name)
plt.show()

# %%
for soil in field_data.soil_type.unique():
    df = field_data
    df = field_data.query('inputs != "Baby"')
    df = df.query(f'soil_type == "{soil}"')
    sns.histplot(df, x="establishment", kde=True, stat='probability', common_norm=False, binwidth=0.05)
    plt.axvline(x=0.85, color='grey')
    plt.xlim(0, 1)
    plt.ylim(0, 1)
    plt.title(f'Soil Type = {soil}')
    plt.savefig(f'{soil} establishment')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-020f2200bfac> in <module>
# ----> 1 for soil in field_data.soil_type.unique():
#       2     df = field_data
#       3     df = field_data.query('inputs != "Baby"')
#       4     df = df.query(f'soil_type == "{soil}"')
#       5     sns.histplot(df, x="establishment", kde=True, stat='probability', common_norm=False, binwidth=0.05)
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'soil_type'

# %%
for soil in field_data.soil_type.unique():
    df = field_data
    df = field_data.query('inputs != "Baby"')
    df = df.query(f'soil_type == "{soil}"')
    sns.histplot(df, x="establishment", hue="method", kde=True, stat='probability', common_norm=False, binwidth=0.05)
    plt.axvline(x=0.85, color='grey')
    plt.xlim(0, 1)
    plt.ylim(0, 1.4)
    plt.title(f'Soil Type = {soil}')
    plt.savefig(f'{soil} establishment by method')
    plt.show()

# %%
df = field_data
df = field_data.query('inputs != "Baby"')
#plt.rcParams['figure.figsize'] = (15,10)
df = df[df['variety'].isin(['Krypton', 'Chiefton', 'Shafton', 'Comanche'])]
sns.histplot(df, x="establishment", hue='variety', kde=True, stat='probability', common_norm=False, binwidth=0.05)
plt.axvline(x=0.85, color='grey')
plt.xlim(0.25,1.25)
plt.ylim(0, 0.6)
plt.savefig('variety establishment comparison')
plt.show()

# %%
def field_comparison(field_list, date_list):
    df = summary_data[summary_data['field'].isin(field_list)]
    print(df.head())
    print(df.tail())
    max_date = df['sample_date'].max()
    print(max_date)
    df = df.query('sample_date == max_date')
    sns.displot(df, x="stripped_diameter", hue="field", kind="kde", fill=True, bw_adjust=2, common_norm=False)
    plt.axvline(x=20, color='grey')
    plt.axvline(x=42, color='grey')
    plt.show()

# %%
field_list = ['Park Farm 31', 'Park Farm 45', 'Park Farm 52']
date_list = ['2021-29-09']

field_comparison(field_list, date_list)
# Out:
#               fieldzone sample_date         field zone  diameter  \
# 79076  Park Farm 31 - 1  2021-07-07  Park Farm 31    1       8.0
# 79077  Park Farm 31 - 1  2021-07-07  Park Farm 31    1       6.0
# 79078  Park Farm 31 - 1  2021-07-07  Park Farm 31    1       9.0
# 79079  Park Farm 31 - 1  2021-07-07  Park Farm 31    1       6.0
# 79080  Park Farm 31 - 1  2021-07-07  Park Farm 31    1       5.0
#
#        stripped_diameter                  fieldzonedate planting_date  \
# 79076               7.36  Park Farm 31 - 1 - 2021-07-07    2021-05-25
# 79077               5.52  Park Farm 31 - 1 - 2021-07-07    2021-05-25
# 79078               8.28  Park Farm 31 - 1 - 2021-07-07    2021-05-25
# 79079               5.52  Park Farm 31 - 1 - 2021-07-07    2021-05-25
# 79080               4.60  Park Farm 31 - 1 - 2021-07-07    2021-05-25
#
#        variety      method        inputs protection  planting_rate  sand  \
# 79076  Krypton  Plant Tape  Conventional       None       206060.0  57.0
# 79077  Krypton  Plant Tape  Conventional       None       206060.0  57.0
# 79078  Krypton  Plant Tape  Conventional       None       206060.0  57.0
# 79079  Krypton  Plant Tape  Conventional       None       206060.0  57.0
# 79080  Krypton  Plant Tape  Conventional       None       206060.0  57.0
#
#        silt  clay  organic_matter harvest_date            fieldvariety  \
# 79076  35.0   8.0             3.5          NaT  Park Farm 31 - Krypton
# 79077  35.0   8.0             3.5          NaT  Park Farm 31 - Krypton
# 79078  35.0   8.0             3.5          NaT  Park Farm 31 - Krypton
# 79079  35.0   8.0             3.5          NaT  Park Farm 31 - Krypton
# 79080  35.0   8.0             3.5          NaT  Park Farm 31 - Krypton
#
#        heat_units  solar_radiation
# 79076           0                0
# 79077           0                0
# 79078           0                0
# 79079           0                0
# 79080           0                0
#               fieldzone sample_date         field zone  diameter  \
# 85369  Park Farm 52 - 4  2021-09-29  Park Farm 52    4      36.0
# 85370  Park Farm 52 - 4  2021-09-29  Park Farm 52    4      23.0
# 85371  Park Farm 52 - 4  2021-09-29  Park Farm 52    4      31.0
# 85372  Park Farm 52 - 4  2021-09-29  Park Farm 52    4      26.0
# 85373  Park Farm 52 - 4  2021-09-29  Park Farm 52    4      29.0
#
#        stripped_diameter                  fieldzonedate planting_date  \
# 85369              33.12  Park Farm 52 - 4 - 2021-09-29    2021-04-01
# 85370              21.16  Park Farm 52 - 4 - 2021-09-29    2021-04-01
# 85371              28.52  Park Farm 52 - 4 - 2021-09-29    2021-04-01
# 85372              23.92  Park Farm 52 - 4 - 2021-09-29    2021-04-01
# 85373              26.68  Park Farm 52 - 4 - 2021-09-29    2021-04-01
#
#        variety   method        inputs protection  planting_rate  sand  silt  \
# 85369  Krypton  Drilled  Conventional     Barley       260538.0  28.0  58.0
# 85370  Krypton  Drilled  Conventional     Barley       260538.0  28.0  58.0
# 85371  Krypton  Drilled  Conventional     Barley       260538.0  28.0  58.0
# 85372  Krypton  Drilled  Conventional     Barley       260538.0  28.0  58.0
# 85373  Krypton  Drilled  Conventional     Barley       260538.0  28.0  58.0
#
#        clay  organic_matter harvest_date            fieldvariety  heat_units  \
# 85369  14.0            35.0          NaT  Park Farm 52 - Krypton           0
# 85370  14.0            35.0          NaT  Park Farm 52 - Krypton           0
# 85371  14.0            35.0          NaT  Park Farm 52 - Krypton           0
# 85372  14.0            35.0          NaT  Park Farm 52 - Krypton           0
# 85373  14.0            35.0          NaT  Park Farm 52 - Krypton           0
#
#        solar_radiation
# 85369                0
# 85370                0
# 85371                0
# 85372                0
# 85373                0
# 2021-09-29 00:00:00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     200             if self.has_resolvers:
# --> 201                 return self.resolvers[key]
#     202
#
# c:\users\tom\appdata\local\programs\python\python39\lib\collections\__init__.py in __getitem__(self, key)
#     940                 pass
# --> 941         return self.__missing__(key)            # support subclasses that define __missing__
#     942
#
# c:\users\tom\appdata\local\programs\python\python39\lib\collections\__init__.py in __missing__(self, key)
#     932     def __missing__(self, key):
# --> 933         raise KeyError(key)
#     934
#
# KeyError: 'max_date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     211                 # e.g., df[df > 0]
# --> 212                 return self.temps[key]
#     213             except KeyError as err:
#
# KeyError: 'max_date'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-19-e26cd3dfeadb> in <module>
#       2 date_list = ['2021-29-09']
#       3
# ----> 4 field_comparison(field_list, date_list)
#
# <ipython-input-18-2f7974b8eb29> in field_comparison(field_list, date_list)
#       5     max_date = df['sample_date'].max()
#       6     print(max_date)
# ----> 7     df = df.query('sample_date == max_date')
#       8     sns.displot(df, x="stripped_diameter", hue="field", kind="kde", fill=True, bw_adjust=2, common_norm=False)
#       9     plt.axvline(x=20, color='grey')
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3464         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3465         kwargs["target"] = None
# -> 3466         res = self.eval(expr, **kwargs)
#    3467
#    3468         try:
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    3594         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3595
# -> 3596         return _eval(expr, inplace=inplace, **kwargs)
#    3597
#    3598     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     340         )
#     341
# --> 342         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     343
#     344         # construct the engine and evaluate the parsed expression
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in __init__(self, expr, engine, parser, env, level)
#     796         self.parser = parser
#     797         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 798         self.terms = self.parse()
#     799
#     800     @property
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in parse(self)
#     815         Parse an expression.
#     816         """
# --> 817         return self._visitor.visit(self.expr)
#     818
#     819     @property
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit_Module(self, node, **kwargs)
#     405             raise SyntaxError("only a single expression is allowed")
#     406         expr = node.body[0]
# --> 407         return self.visit(expr, **kwargs)
#     408
#     409     def visit_Expr(self, node, **kwargs):
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit_Expr(self, node, **kwargs)
#     408
#     409     def visit_Expr(self, node, **kwargs):
# --> 410         return self.visit(node.value, **kwargs)
#     411
#     412     def _rewrite_membership_op(self, node, left, right):
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit_Compare(self, node, **kwargs)
#     708             op = self.translate_In(ops[0])
#     709             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 710             return self.visit(binop)
#     711
#     712         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit_BinOp(self, node, **kwargs)
#     520
#     521     def visit_BinOp(self, node, **kwargs):
# --> 522         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     523         left, right = self._maybe_downcast_constants(left, right)
#     524         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     442             left = self.visit(node.left, side="left")
#     443         if right is None:
# --> 444             right = self.visit(node.right, side="right")
#     445         op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     446         return op, op_class, left, right
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expr.py in visit_Name(self, node, **kwargs)
#     533
#     534     def visit_Name(self, node, **kwargs):
# --> 535         return self.term_type(node.id, self.env, **kwargs)
#     536
#     537     def visit_NameConstant(self, node, **kwargs):
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\ops.py in __init__(self, name, env, side, encoding)
#      84         tname = str(name)
#      85         self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 86         self._value = self._resolve_name()
#      87         self.encoding = encoding
#      88
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\ops.py in _resolve_name(self)
#     101
#     102     def _resolve_name(self):
# --> 103         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     104         self.update(res)
#     105
#
# c:\users\tom\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     215                 from pandas.core.computation.ops import UndefinedVariableError
#     216
# --> 217                 raise UndefinedVariableError(key, is_local) from err
#     218
#     219     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'max_date' is not defined
