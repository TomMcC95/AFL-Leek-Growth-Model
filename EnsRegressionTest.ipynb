# %%
# Run preprocessing script to make dataframe objects available.

# %run EnsRegressionEval.ipynb
# Out:
# Current Progress: 100.0 %
# The old training dataframe shape: (2911, 8)
# Total number of outliers identified is:  146
# The new training dataframe shape: (2765, 8)
# 0.9136604303889184
# 2.460806156357698
# 5.651100670641856
# 0.4044662685260931

# %%
indicator_variables_list = ['pp2m2','heat_units','solar_radiation','organic_matter', 'method','variety','inputs','protection']

zone_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837 entries, 0 to 836
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   field                      837 non-null    object
#  1   zone                       837 non-null    int32
#  2   planting_date              837 non-null    datetime64[ns]
#  3   variety                    837 non-null    object
#  4   method                     837 non-null    object
#  5   inputs                     837 non-null    object
#  6   protection                 837 non-null    object
#  7   planting_rate              837 non-null    int64
#  8   sand                       837 non-null    int64
#  9   silt                       837 non-null    int64
#  10  clay                       837 non-null    int64
#  11  organic_matter             837 non-null    float64
#  12  harvest_date               837 non-null    datetime64[ns]
#  13  fieldzone                  837 non-null    object
#  14  fieldvariety               837 non-null    object
#  15  mean_pp2m2                 837 non-null    float64
#  16  max_sample_date            837 non-null    object
#  17  max_mean_diameter_lin      837 non-null    float64
#  18  max_std_dev_diameter_lin   837 non-null    float64
#  19  max_heat                   837 non-null    float64
#  20  max_solar                  837 non-null    float64
#  21  remaining_heat             837 non-null    float64
#  22  remaining_solar            837 non-null    float64
#  23  rain_after_planting        837 non-null    float64
#  24  establishment              837 non-null    float64
#  25  est_mean_diameter_gain     837 non-null    float64
#  26  est_std_dev_diameter_gain  837 non-null    float64
#  27  est_mean_diameter          837 non-null    float64
#  28  est_std_dev_diameter       837 non-null    float64
# dtypes: datetime64[ns](2), float64(14), int32(1), int64(4), object(8)
# memory usage: 186.5+ KB

# %%
planting_data = zone_data.copy()[['fieldvariety',
                                  'variety',
                                  'method',
                                  'inputs',
                                  'protection',
                                  'sand',
                                  'silt',
                                  'clay',
                                  'organic_matter',
                                  'mean_pp2m2',
                                  'max_heat',
                                  'max_solar',
                                  'remaining_heat',
                                  'remaining_solar',
                                  ]].loc[(zone_data['planting_date'] > season)]

planting_data['heat_units'] = planting_data['max_heat'] + planting_data['remaining_heat']
planting_data['solar_radiation'] = planting_data['max_solar'] + planting_data['remaining_solar']

planting_data = planting_data.groupby(['fieldvariety']).agg({'method' : ['first'],
                                                             'inputs' : ['first'],
                                                             'variety' : ['first'],
                                                             'protection' : ['first'],
                                                             'sand' : ['mean'],
                                                             'silt' : ['mean'],
                                                             'clay' : ['mean'],
                                                             'organic_matter' : ['mean'],
                                                             'mean_pp2m2' : ['mean'],
                                                             'heat_units' : ['mean'],
                                                             'solar_radiation' : ['mean']}).reset_index()

planting_data.columns = ['fieldvariety',
                         'method',
                         'inputs',
                         'variety',
                         'protection',
                         'sand',
                         'silt',
                         'clay',
                         'organic_matter',
                         'pp2m2',
                         'heat_units',
                         'solar_radiation']

# %%
print(planting_data.shape)
planting_data
# Out:
# (82, 12)
#                          fieldvariety          method        inputs   variety  \
# 0                Allans 15 - Chiefton         Drilled  Conventional  Chiefton
# 1                Allans 23 - Chiefton         Drilled  Conventional  Chiefton
# 2         Allans Long Drove - Krypton      Plant Tape  Conventional   Krypton
# 3             Bridge Field - Chiefton         Modules       Organic  Chiefton
# 4       Buckenham Eelsfoot - Chiefton         Drilled  Conventional  Chiefton
# 5               Butcher 16 - Chiefton         Drilled  Conventional  Chiefton
# 6               Butcher 39 - Chiefton         Drilled  Conventional  Chiefton
# 7         Chatteris Farms 40 - Laston      Plant Tape  Conventional    Laston
# 8         Garretts Decoy 1 - Comanche         Drilled  Conventional  Comanche
# 9         Garretts Decoy 2 - Comanche         Drilled  Conventional  Comanche
# 10      Garretts Listers 14 - Krypton         Drilled  Conventional   Krypton
# 11      Garretts Listers 15 - Krypton         Drilled  Conventional   Krypton
# 12           Grotec Auction - Krypton      Bare Roots  Conventional   Krypton
# 13        Grotec Near Black - Krypton      Plant Tape  Conventional   Krypton
# 14            Grotec Sewage - Krypton      Bare Roots  Conventional   Krypton
# 15                Guyers 15 - Linkton         Drilled  Conventional   Linkton
# 16               Guyers 16 - Chiefton         Drilled  Conventional  Chiefton
# 17                     HB74 - Linkton          Blocks  Conventional   Linkton
# 18                     HB75 - Shafton          Blocks  Conventional   Shafton
# 19                      HH28 - Lexton         Drilled  Conventional    Lexton
# 20                    HH36A - Linkton         Drilled          Baby   Linkton
# 21                    HH36B - Linkton         Drilled          Baby   Linkton
# 22                     HH36C - Runner         Drilled          Baby    Runner
# 23                    HH36D - Linkton         Drilled          Baby   Linkton
# 24                     HH36D - Runner         Drilled          Baby    Runner
# 25                    HH36E - Linkton         Drilled          Baby   Linkton
# 26                     HH36E - Runner         Drilled          Baby    Runner
# 27                     HH36F - Runner         Drilled          Baby    Runner
# 28                    HH36G - Linkton         Drilled          Baby   Linkton
# 29                     HH36G - Runner         Drilled          Baby    Runner
# 30                      HH42 - Laston         Drilled  Conventional    Laston
# 31                     HH45A - Runner         Drilled          Baby    Runner
# 32                    HH45B - Linkton         Drilled          Baby   Linkton
# 33                     HH45B - Runner         Drilled          Baby    Runner
# 34                    HH45C - Linkton         Drilled          Baby   Linkton
# 35                     HH45C - Runner         Drilled          Baby    Runner
# 36                     HH45D - Lexton         Drilled          Baby    Lexton
# 37                     HH45D - Runner         Drilled          Baby    Runner
# 38                     HH45E - Lexton         Drilled          Baby    Lexton
# 39             John Allan 2 - Krypton         Drilled  Conventional   Krypton
# 40             John Allan 3 - Krypton         Drilled  Conventional   Krypton
# 41             John Allan 4 - Krypton         Drilled  Conventional   Krypton
# 42             John Allan 5 - Krypton         Drilled  Conventional   Krypton
# 43          Lords Ground 24 - Linkton          Blocks  Conventional   Linkton
# 44          Lords Ground 36 - Krypton          Blocks  Conventional   Krypton
# 45          Lords Ground 51 - Shafton          Blocks  Conventional   Shafton
# 46          Lords Ground 54 - Shafton          Blocks  Conventional   Shafton
# 47          Lords Ground 58 - Linkton          Blocks  Conventional   Linkton
# 48  Lords Ground White Post - Linkton          Blocks  Conventional   Linkton
# 49              Martin F12 - Chiefton         Modules       Organic  Chiefton
# 50               Martin F12 - Krypton         Modules       Organic   Krypton
# 51                Martin P6 - Krypton  Superseedlings       Organic   Krypton
# 52                Martin P6 - Shafton  Superseedlings       Organic   Shafton
# 53             Park Farm 02 - Krypton      Bare Roots  Conventional   Krypton
# 54                Park Farm 03 - Oslo      Bare Roots  Conventional      Oslo
# 55             Park Farm 04 - Krypton      Plant Tape  Conventional   Krypton
# 56             Park Farm 16 - Krypton      Plant Tape  Conventional   Krypton
# 57            Park Farm 25 - Chiefton      Plant Tape  Conventional  Chiefton
# 58             Park Farm 43 - Krypton         Drilled  Conventional   Krypton
# 59             Park Farm 47 - Krypton         Drilled  Conventional   Krypton
# 60             Park Farm 48 - Krypton         Drilled  Conventional   Krypton
# 61            Park Farm 54 - Chiefton         Drilled  Conventional  Chiefton
# 62                    RH38 - Defender      Bare Roots       Organic  Defender
# 63                      RH38 - Laston      Bare Roots       Organic    Laston
# 64                     RH41 - Harston      Bare Roots  Conventional   Harston
# 65                      RH41 - Laston      Bare Roots  Conventional    Laston
# 66              Rosedene 50 - Krypton         Drilled  Conventional   Krypton
# 67              Rosedene 53 - Krypton         Drilled  Conventional   Krypton
# 68                  Smith 1 - Krypton         Drilled  Conventional   Krypton
# 69                  Smith 2 - Linkton         Drilled  Conventional   Linkton
# 70                Soles 25 - Chiefton         Drilled  Conventional  Chiefton
# 71                Soles 27 - Chiefton         Drilled  Conventional  Chiefton
# 72     Spencers Church Pit C - Belton         Modules       Organic    Belton
# 73   Spencers Church Pit C - Defender         Modules       Organic  Defender
# 74       Spencers Church Pit C - Oslo         Modules       Organic      Oslo
# 75   Spencers Church Pit D - Defender      Bare Roots       Organic  Defender
# 76         Symmingtons HF3 - Chiefton      Plant Tape  Conventional  Chiefton
# 77          Symmingtons HF3 - Pluston      Plant Tape  Conventional   Pluston
# 78                Wissey 22 - Shafton         Drilled  Conventional   Shafton
# 79                Wissey 32 - Krypton         Drilled  Conventional   Krypton
# 80             Wissey C (N) - Shafton         Drilled  Conventional   Shafton
# 81             Wissey C (S) - Krypton         Drilled  Conventional   Krypton
#
#    protection  sand  silt  clay  organic_matter  pp2m2   heat_units  \
# 0      Barley    45    47     8            20.0   40.0  2481.458021
# 1      Barley    40    51     9            17.0   40.0  2528.547604
# 2        None    40    45    15            20.0   40.0  1687.138021
# 3        None    38    50    12             1.2   40.0  1813.729092
# 4      Barley    66    30     4            10.0   40.0  2335.840476
# 5      Barley    65    31     4             5.0   40.0  2443.448497
# 6      Barley    57    37     6             5.0   40.0  2443.448497
# 7        None    36    56     8            10.0   40.0  1904.797604
# 8      Barley    85    13     2            81.0   40.0  1390.821057
# 9      Barley    83    16     1            80.0   40.0  1817.310640
# 10     Barley    80    18     2            48.0   40.0  1817.310640
# 11     Barley    80    19     1            45.0   40.0  1817.310640
# 12       None    58    35     7             2.5   40.0  1994.746042
# 13       None    60    35     5            30.0   40.0  2000.021354
# 14       None    40    46    14            14.0   40.0  1994.746042
# 15     Barley    75    23     2            65.0   40.0  2297.065327
# 16     Barley    85    14     1            67.0   40.0  2435.018452
# 17       None    34    37    29            39.0   40.0  1192.888914
# 18       None     8    56    36            23.5   40.0  1569.508854
# 19     Barley    35    57     8            11.0   40.0  2440.668437
# 20       Poly     4    47    49            33.0   40.0   940.039807
# 21       Poly     4    47    49            33.0   40.0   912.077307
# 22       Poly     4    47    49            33.0   40.0  1331.637723
# 23       Poly     4    47    49            33.0   40.0  1292.066890
# 24       Poly     4    47    49            33.0   40.0  1292.066890
# 25     Barley     4    47    49            33.0   40.0  1269.264509
# 26     Barley     4    47    49            33.0   40.0  1269.264509
# 27     Barley     4    47    49            33.0   40.0  1230.898438
# 28     Barley     4    47    49            33.0   40.0  1619.378497
# 29     Barley     4    47    49            33.0   40.0  1619.378497
# 30     Barley    27    44    29            16.1   40.0  2440.668437
# 31     Barley    44    48     8            20.0   40.0  1569.508854
# 32     Barley    44    48     8            20.0   40.0  1533.377902
# 33     Barley    44    48     8            20.0   40.0  1862.573735
# 34     Barley    44    48     8            20.0   40.0  1813.729092
# 35     Barley    44    48     8            20.0   40.0  1813.729092
# 36     Barley    44    48     8            20.0   40.0  2003.419271
# 37     Barley    44    48     8            20.0   40.0  2003.419271
# 38     Barley    44    48     8            20.0   40.0  2074.404167
# 39     Barley    80    19     1            75.0   40.0  2235.896875
# 40     Barley    82    16     2            76.0   40.0  2235.896875
# 41     Barley    82    16     2            75.0   40.0  2373.850000
# 42     Barley    87    12     1            75.0   40.0  2373.850000
# 43     Fleece     1    52    47            48.9   40.0   912.077307
# 44       None     4    47    49            33.0   40.0   780.117188
# 45       None     7    51    42            21.2   40.0   818.483259
# 46     Fleece     5    56    39            28.7   40.0  1292.066890
# 47     Fleece     4    48    48            26.2   40.0   880.856473
# 48       None     3    62    35            51.0   40.0   742.107664
# 49       None    48    42    10            24.0   40.0  1533.377902
# 50       None    48    42    10            24.0   40.0  1569.508854
# 51     Fleece    34    55    11            20.0   40.0  1264.107366
# 52     Fleece    34    55    11            20.0   40.0   880.856473
# 53       None    37    47    16             1.8   40.0  1904.797604
# 54       None    41    41    18             2.0   40.0  1673.828854
# 55       None    44    42    14             2.2   40.0  2000.021354
# 56       None    56    38     6            10.0   40.0  2027.904896
# 57       None    45    46     9            20.0   40.0  2074.994479
# 58     Barley    66    30     4            30.0   40.0  2589.716057
# 59     Barley    75    23     2            35.0   40.0  2589.716057
# 60     Barley    75    22     3            34.0   40.0  2542.626473
# 61     Barley    69    27     4            30.0   40.0  2297.065327
# 62       None    49    37    14             3.4   40.0  1994.746042
# 63       None    49    37    14             3.4   40.0  1904.797604
# 64       None    30    52    18             2.8   40.0  1415.042396
# 65       None    30    52    18             2.8   40.0  1525.571562
# 66     Barley    79    19     2            67.0   40.0  2047.752307
# 67     Barley    85    14     1            75.0   40.0  1718.556473
# 68     Barley    81    17     2            74.0   40.0  2533.772619
# 69     Barley    80    17     3            74.0   40.0  2146.506473
# 70     Barley    65    32     3            57.0   40.0  2528.547604
# 71     Barley    65    32     3            57.0   40.0  2528.547604
# 72       None    33    55    12             2.5   40.0  2107.629375
# 73       None    33    55    12             2.5   40.0  2074.404167
# 74       None    33    55    12             2.5   40.0  2141.372396
# 75       None    33    55    12             2.5   40.0  2027.904896
# 76       None    35    49    16             2.0   40.0  1812.566875
# 77       None    35    49    16             2.0   40.0  1812.566875
# 78     Barley    80    19     1            69.0   40.0  2395.819494
# 79     Barley    74    23     3            72.0   40.0  2146.506473
# 80     Barley    72    25     3            68.0   40.0  2395.819494
# 81     Barley    75    23     2            70.0   40.0  2146.506473
#
#     solar_radiation
# 0      1.694261e+06
# 1      1.722285e+06
# 2      1.125598e+06
# 3      1.266702e+06
# 4      1.607431e+06
# 5      1.637210e+06
# 6      1.637210e+06
# 7      1.039813e+06
# 8      1.324255e+06
# 9      1.560461e+06
# 10     1.560461e+06
# 11     1.560461e+06
# 12     1.109388e+06
# 13     1.192147e+06
# 14     1.109388e+06
# 15     1.705244e+06
# 16     1.752014e+06
# 17     1.054437e+06
# 18     1.218364e+06
# 19     1.592955e+06
# 20     1.015592e+06
# 21     9.822788e+05
# 22     1.249220e+06
# 23     1.199019e+06
# 24     1.199019e+06
# 25     1.161236e+06
# 26     1.161236e+06
# 27     1.111487e+06
# 28     1.290643e+06
# 29     1.290643e+06
# 30     1.592955e+06
# 31     1.218364e+06
# 32     1.161141e+06
# 33     1.336680e+06
# 34     1.266702e+06
# 35     1.266702e+06
# 36     1.294639e+06
# 37     1.294639e+06
# 38     1.266847e+06
# 39     1.617712e+06
# 40     1.617712e+06
# 41     1.664482e+06
# 42     1.664482e+06
# 43     9.822788e+05
# 44     8.028246e+05
# 45     8.525736e+05
# 46     1.199019e+06
# 47     9.405572e+05
# 48     7.457741e+05
# 49     1.161141e+06
# 50     1.218364e+06
# 51     1.155327e+06
# 52     9.405572e+05
# 53     1.039813e+06
# 54     8.679251e+05
# 55     1.192147e+06
# 56     1.155270e+06
# 57     1.183294e+06
# 58     1.809817e+06
# 59     1.809817e+06
# 60     1.781793e+06
# 61     1.705244e+06
# 62     1.109388e+06
# 63     1.039813e+06
# 64     6.837860e+05
# 65     7.595522e+05
# 66     1.610765e+06
# 67     1.435226e+06
# 68     1.877249e+06
# 69     1.736000e+06
# 70     1.722285e+06
# 71     1.722285e+06
# 72     1.221926e+06
# 73     1.266847e+06
# 74     1.341408e+06
# 75     1.155270e+06
# 76     9.690255e+05
# 77     9.690255e+05
# 78     1.830480e+06
# 79     1.736000e+06
# 80     1.830480e+06
# 81     1.736000e+06

# %%
indicator_data = planting_data.reindex(columns=indicator_variables_list)
                                      
indicator_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pp2m2            82 non-null     float64
#  1   heat_units       82 non-null     float64
#  2   solar_radiation  82 non-null     float64
#  3   organic_matter   82 non-null     float64
#  4   method           82 non-null     object
#  5   variety          82 non-null     object
#  6   inputs           82 non-null     object
#  7   protection       82 non-null     object
# dtypes: float64(4), object(4)
# memory usage: 5.2+ KB

# %%
# Encode categoriccal variables that will be used as predictors

pd.options.mode.chained_assignment = None  # default='warn'

encoded_array = trns.transform(indicator_data[['method', 'variety', 'inputs', 'protection']])
indicator_data.loc[:, ['method', 'variety', 'inputs', 'protection']] = encoded_array.copy()

indicator_data.head()
# Out:
#    pp2m2   heat_units  solar_radiation  organic_matter  method  variety  \
# 0   40.0  2481.458021     1.694261e+06            20.0     2.0      4.0
# 1   40.0  2528.547604     1.722285e+06            17.0     2.0      4.0
# 2   40.0  1687.138021     1.125598e+06            20.0     4.0     11.0
# 3   40.0  1813.729092     1.266702e+06             1.2     3.0      4.0
# 4   40.0  2335.840476     1.607431e+06            10.0     2.0      4.0
#
#    inputs  protection
# 0     1.0         0.0
# 1     1.0         0.0
# 2     1.0         2.0
# 3     2.0         2.0
# 4     1.0         0.0

# %%
preds = ens.predict(indicator_data)

planting_data['predictions'] = preds
planting_data = planting_data.sort_values(by=['method', 'fieldvariety'])

# %%
for method, a, b, c in [('Baby', 17, 15, 20), ('Conventional', 47, 30, 40), ('Organic', 11, 20, 30)]:
    fig, ax = plt.subplots(figsize=(10, a))
    ax = sns.barplot(y='fieldvariety', x='predictions', data = planting_data[(planting_data.inputs == f"{method}")], hue = 'method', orient = "h")
    plt.axvline(x = b, color = 'red')
    plt.axvline(x = c, color = 'red')
    plt.savefig(f'{method} Predictions.png', dpi=300, bbox_inches = 'tight')
    plt.show()
