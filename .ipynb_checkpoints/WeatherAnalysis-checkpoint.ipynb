# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date

# %%
weather_data_path = "F:\\Farm Data\Growth Model\weather_db.csv"
weather_data = pd.read_csv(weather_data_path)

# %%
weather_data
# Out:
#              date      time  avg_temp     rh  rain  solar_radiation  \
# 0      30/04/2014  05:28:00     25.80  35.60   NaN                0
# 1      30/04/2014  06:00:00     24.50  38.70   0.0                0
# 2      30/04/2014  06:08:00     18.80  48.50   NaN              962
# 3      30/04/2014  07:00:00     18.40  51.60   0.2              812
# 4      14/05/2014  13:53:00     16.70  51.80   NaN              198
# ...           ...       ...       ...    ...   ...              ...
# 59204  01/04/2021  03:00:00      7.21  99.81   0.0                0
# 59205  01/04/2021  04:00:00      7.04  99.81   0.0                0
# 59206  01/04/2021  05:00:00      7.00  99.81   0.0                0
# 59207  01/04/2021  06:00:00      7.44  99.81   0.0                0
# 59208  01/04/2021  07:00:00      7.41  99.82   0.0               26
#
#        wind_speed  bat_volt  leaf_wet  dew_point
# 0             NaN    6660.0       0.0        9.2
# 1             0.0    6698.0       0.0        9.3
# ...

# %%
weather_data['date'] = pd.to_datetime(weather_data['date'])
weather_data = weather_data.loc[(weather_data['date'] >= '2020-01-01') & (weather_data['date'] < '2020-12-31')]
weather_data.index = weather_data['date']

weather_data['avg_temp'].plot(figsize=(15, 6))
plt.show()
